# %% [markdown]
# <center> <h1>Universidad Nacional de San Agustín de Arequipa</h1> </center>
# <center> <h1>Escuela Profesional de Ingeniería de</h1> </center>
# <center> <h1>Telecomunicaciones</h1> </center>

# %% [markdown]
# ![](https://live.staticflickr.com/3237/2298687478_0ecc6fb58b_z.jpg)

# %% [markdown]
# <center> <h1>Ingeniero Renzo Bolivar - Docente DAIE </h1> </center>
# <center> <h1>Estudiante: Rony Ticona</h1> </center>

# %% [markdown]
# ![finalsepazull.png](attachment:finalsepazull.png)

# %% [markdown]
# <center> <h1>PYTHON</h1> </center>
# <center> <h1>Funciones y Excepciones</h1> </center>

# %% [markdown]
# ![](https://sindicatoaudiovisual.com/wp-content/uploads/2016/05/linea-roja-titulo.png)

# %% [markdown]
# <center> <h1>DESARROLLO</h1> </center>

# %% [markdown]
# ![](https://sindicatoaudiovisual.com/wp-content/uploads/2016/05/linea-roja-titulo.png)

# %% [markdown]
# ![separador-puntos-azul.jpg](attachment:separador-puntos-azul.jpg)

# %% [markdown]
# # <font color='blue'>**1. Estructura Excepciones**</font>

# %% [markdown]
# <font color='sky blue'>Las **Excepciones** se utilizan para **evitar** cortes durante la ejecución del programa. </font>

# %% [markdown]
# **Típicos Errores**

# %%
1/0
z = 25
print(z)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_3421/3610794940.py in <module>
# ----> 1 1/0
#       2 z = 25
#       3 print(z)
#
# ZeroDivisionError: division by zero

# %%
n = int(input())
z = 25
print(z)
# Out:
# ewqrewer
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3421/1587764996.py in <module>
# ----> 1 n = int(input())
#       2 z = 25
#       3 print(z)
#
# ValueError: invalid literal for int() with base 10: 'ewqrewer'

# %% [markdown]
# **Validación de números:**

# %%
#validar ingreso de numero enteros
while True:
    try:
        x = int(input('Ingresar un numero: '))
        break
    except ValueError:
        print('Error!!! no es numero valido')
# Out:
# Ingresar un numero: !·"%&(/
# Error!!! no es numero valido
# Ingresar un numero: qwerere
# Error!!! no es numero valido
# Ingresar un numero: 1234a
# Error!!! no es numero valido
# Ingresar un numero: 1234321

# %% [markdown]
# **Validación de números y otra condición:**

# %%
#validar ingreso de numeros enteros positivos
while True:
    try:
        x = int(input('Ingresar un numero positivo: '))
    except ValueError:
        print('Error!!! no es numero positivo valido')
        continue
    if x < 0:
        print('\t Por favor ingrese un número positivo')
        continue
    break
# Out:
# Ingresar un numero positivo: 2323243"·%&
# Error!!! no es numero positivo valido
# Ingresar un numero positivo: awqerqw
# Error!!! no es numero positivo valido
# Ingresar un numero positivo: -122
# 	 Por favor ingrese un número positivo
# Ingresar un numero positivo: 524

# %% [markdown]
# -------------

# %% [markdown]
# **Estructura Funciones**

# %% [markdown]
# <font color='sky blue'>¿Por qué utilizar Funciones?</font>
# * La creación de una nueva función le da la oportunidad de nombrar un grupo de sentencias, lo que hace que su programa sea más fácil de leer y depurar.
# * Las funciones pueden hacer que un programa sea más pequeño eliminando el código repetitivo. Más tarde, si haces un cambio, sólo tienes que hacerlo en un lugar.
# * Dividir un programa largo en funciones le permite depurar las partes de una en una y luego ensamblarlas en un todo de trabajo.
# * Las funciones bien diseñadas son a menudo útiles para muchos programas. Una vez que escribes y depuras uno, puedes reutilizarlo

# %% [markdown]
# -------

# %% [markdown]
# **Funciones Principal main**

# %%
#Inicio mis programas con varias funciones
def uno():
    print('Inicio de Programa')
    
def dos():
    pass
    
def fin():
    print('\n\n\n Fin del programa')
    
#Programa MAIN principal
if __name__ == '__main__':
    uno()
    dos()
    uno()
    dos()
    fin()
# Out:
# Inicio de Programa
# Inicio de Programa
#
#
#
#  Fin del programa

# %% [markdown]
# **Hacer un programa que solicite ingreso de DNI correctamente:**

# %%
#MI primera función validar dni
def validar_dni():
    while True:
        try:
            dni = int(input('Ingresa DNI: '))
            if len(str(dni)) == 8:
                print('\n\tDNI VÁLIDO')
                break
            else:
                print('\tError! Longitud de DNI no Válido ... Intente de nuevo')
                continue
                
        except ValueError:
            print('\tError!!! NO es un DNI Válido... Intente de Nuevo')
            
    return dni
    
#Programa MAIN principal
if __name__ == '__main__':
    titulo = ('    BONO FAMILIAR UNIVERSAL    ')
    print (titulo.center(50,'*'))
    print('\n\n')
    
    val_dni = validar_dni()
    
    print('\n\n El DNI Ingresado es: ==>',val_dni)
# Out:
# *********    BONO FAMILIAR UNIVERSAL    **********
#
#
#
# Ingresa DNI: "$·$%%%&
# 	Error!!! NO es un DNI Válido... Intente de Nuevo
# Ingresa DNI: qertyui
# 	Error!!! NO es un DNI Válido... Intente de Nuevo
# Ingresa DNI: 321546546848464
# 	Error! Longitud de DNI no Válido ... Intente de nuevo
# Ingresa DNI: 87549632
#
# 	DNI VÁLIDO
#
#
#  El DNI Ingresado es: ==> 87549632

# %% [markdown]
# ![separador-puntos-azul.jpg](attachment:separador-puntos-azul.jpg)

# %% [markdown]
# ![](https://sindicatoaudiovisual.com/wp-content/uploads/2016/05/linea-roja-titulo.png)

# %% [markdown]
# <center> <h1>EJEMPLOS</h1> </center>

# %% [markdown]
# ![](https://sindicatoaudiovisual.com/wp-content/uploads/2016/05/linea-roja-titulo.png)

# %% [markdown]
# ![separador-puntos-azul.jpg](attachment:separador-puntos-azul.jpg)

# %% [markdown]
# # <font color='blue'>EJEMPLOS</font>

# %% [markdown]
# -------

# %% [markdown]
# **Hacer un programa que imprima un menú de opciones y que valide
# correctamente los ingresos:**

# %%
#LIBRERÍA DEL SISTEMA OPERATIVO
import os



def menu():
    """
    Funcion que limpia la pantalla y muestra nuevamente el menu 
    """
    os.system('clear') # Borra pantalla en un terminal, en Jupyter no funciona 
    titulo = ("  Menú General  ")
    print (titulo.center(50,'*'))
    print ('\n\n')
    print ("Selecciona una Opción")
    print ("\t1 - Primera Opción")
    print ("\t2 - Segunda Opción")
    print ("\t3 - Tercera Opción")
    print ("\t9 - Salir")
    
def validar():
    while True:
        #Mostramos el menú
        menu()
        
        #solicitamos una opción al usuario
        opcionMenu = input("inserta un numero valor >> ")
        
        if opcionMenu=="1":
            print ("")
            input("Has pulsado la opción 1...\npulsa una tecla para continuar")
        elif opcionMenu=="2":
            print ("")
            input("Has pulsado la opción 2...\npulsa una tecla para continuar")
        elif opcionMenu=="3":
            print ("")
            input("Has pulsado la opción 3...\npulsa una tecla para continuar")
        elif opcionMenu=="9":
            break
        else:
            print ("")
            input("No has pulsado ninguna opcion correcta... \npulsa una tecla para continuar")
    return opcionMenu

if __name__ == '__main__':
    validar()
    
    print('\tFINALIZÓ EL PROGRAMA!!!')
# Out:
# *****************  Menú General  *****************
#
#
#
# Selecciona una Opción
# 	1 - Primera Opción
# 	2 - Segunda Opción
# 	3 - Tercera Opción
# 	9 - Salir
# inserta un numero valor >> "R·/($&/
#
# No has pulsado ninguna opcion correcta...
# pulsa una tecla para continuarfwegtweg
# *****************  Menú General  *****************
#
#
#
# Selecciona una Opción
# 	1 - Primera Opción
# 	2 - Segunda Opción
# 	3 - Tercera Opción
# 	9 - Salir
# inserta un numero valor >> 1651684
#
# No has pulsado ninguna opcion correcta...
# pulsa una tecla para continuar165161"·$
# *****************  Menú General  *****************
#
#
#
# Selecciona una Opción
# 	1 - Primera Opción
# 	2 - Segunda Opción
# 	3 - Tercera Opción
# 	9 - Salir
# inserta un numero valor >> 8
#
# No has pulsado ninguna opcion correcta...
# pulsa una tecla para continuar1
# *****************  Menú General  *****************
#
#
#
# Selecciona una Opción
# 	1 - Primera Opción
# 	2 - Segunda Opción
# 	3 - Tercera Opción
# ...

# %% [markdown]
# ![separador-puntos-azul.jpg](attachment:separador-puntos-azul.jpg)

# %% [markdown]
# ![](https://sindicatoaudiovisual.com/wp-content/uploads/2016/05/linea-roja-titulo.png)

# %% [markdown]
# <center> <h1>EJERCICIOS</h1> </center>

# %% [markdown]
# ![](https://sindicatoaudiovisual.com/wp-content/uploads/2016/05/linea-roja-titulo.png)

# %% [markdown]
# # <center><h1><font color='violet'>**FIN**</font></h1></center>
# ![separadorfinal.png](attachment:separadorfinal.png)
